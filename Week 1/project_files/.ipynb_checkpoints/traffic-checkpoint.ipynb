# %%
import pandas as pd
import matplotlib as plt
import os
from pathlib import Path
from datetime import datetime

# %%
print("Goodbye Space")
# Out:
# Goodbye Space

# %%
df = pd.read_csv("rtd.csv")

# %%
# df.shape
# df.columns
# df.info()
# df.describe()

# %%
ir = df["Issue Reported"]

print(ir.unique(), "\n")
print(ir.value_counts())
# Out:
# <StringArray>
# [           'Stalled Vehicle',               'Crash Urgent',
#             'LOOSE LIVESTOCK',          'TRFC HAZD/ DEBRIS',
#              'Traffic Hazard',                  'COLLISION',
#  'COLLISION/PRIVATE PROPERTY',          'FLEET ACC/ INJURY',
#               'Crash Service',      'COLLISION WITH INJURY',
#           'COLLISN/ LVNG SCN',           'zSTALLED VEHICLE',
#               'BOAT ACCIDENT',               'VEHICLE FIRE',
#           'BLOCKED DRIV/ HWY',           'TRAFFIC FATALITY',
#                   'AUTO/ PED',         'Traffic Impediment',
#          'N / HZRD TRFC VIOL',                'ICY ROADWAY',
#             'COLLISN / FTSRA',           'FLEET ACC/ FATAL',
#                'OBSTRUCT HWY',                 'HIGH WATER']
# Length: 24, dtype: str
#
# Issue Reported
# Traffic Hazard                138183
# Crash Urgent                  115853
# Crash Service                  63587
# COLLISION                      50256
# TRFC HAZD/ DEBRIS              37503
# COLLISION WITH INJURY          12676
# LOOSE LIVESTOCK                12562
# Stalled Vehicle                10826
# COLLISN/ LVNG SCN               9836
# zSTALLED VEHICLE                8930
# Traffic Impediment              6255
# COLLISION/PRIVATE PROPERTY      2058
# VEHICLE FIRE                    1940
# BLOCKED DRIV/ HWY               1051
# AUTO/ PED                        229
# ICY ROADWAY                      139
# BOAT ACCIDENT                    138
# TRAFFIC FATALITY                 136
# FLEET ACC/ INJURY                 69
# OBSTRUCT HWY                      18
# N / HZRD TRFC VIOL                13
# HIGH WATER                         7
# FLEET ACC/ FATAL                   3
# COLLISN / FTSRA                    1
# Name: count, dtype: int64

# %%
ih35 = df[df["Address"].str.contains("IH 35", na=False)]

# %%
# urgent = df[df["Issue Reported"] == "Crash Urgent"]
urgent = df["Issue Reported"] == "Crash Urgent"

# %%
ih35[urgent]
# Out:
# /tmp/ipykernel_859/188159042.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   ih35[urgent]
#                                         Traffic Report ID  \
# 17      7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17096...
# 149     508DE84D9E60D0EA4F80173324A7A9CC95DBEDB3_17122...
# 213     5F5898E4726001663BA5A126B313B03B1AED3F07_17097...
# 215     EC10DB9185C9C58A004FA683DD21AFCD16CAD418_17109...
# 289     BA2E8AA59E4161EE5807078F7226C405FDE751A6_15609...
# ...                                                   ...
# 470908  0DCEDD9FF2B9E09E7BF85EEEC8CA731A3D606372_17735...
# 470966  7FCDB7BA6DE74B6E007EFE1079540E0228817D26_17735...
# 471372  AAEAE9503F54F2A5E567D9F98C62923058C68889_17738...
# 471399  B369414C7CF027CAD9F6D8D9681B1B123DB8477F_17739...
# 472038  AAEAE9503F54F2A5E567D9F98C62923058C68889_17742...
#
#                  Published Date Issue Reported                      Location  \
# 17      2024 Mar 06 02:30:38 AM   Crash Urgent  POINT (-97.696568 30.346648)
# 149     2024 Apr 04 09:57:57 PM   Crash Urgent  POINT (-97.719288 30.295057)
# 213     2024 Mar 06 04:59:46 PM   Crash Urgent   POINT (-97.67169 30.423909)
# 215     2024 Mar 20 02:29:08 PM   Crash Urgent  POINT (-97.753967 30.213333)
# 289     2019 Jun 19 11:26:40 PM   Crash Urgent  POINT (-97.737007 30.256942)
# ...                         ...            ...                           ...
# 470908  2026 Mar 14 03:20:33 PM   Crash Urgent  POINT (-97.672546 30.386505)
# 470966  2026 Mar 14 11:47:36 PM   Crash Urgent  POINT (-97.731784 30.274747)
# 471372  2026 Mar 18 09:36:04 AM   Crash Urgent  POINT (-97.770856 30.189791)
# 471399  2026 Mar 19 10:06:58 PM   Crash Urgent   POINT (-97.688077 30.35796)
# 472038  2026 Mar 23 10:44:09 AM   Crash Urgent  POINT (-97.682394 30.367782)
#
#          Latitude  Longitude                         Address    Status  \
# 17      30.346648 -97.696568            8312 N IH 35 SVRD SB  ARCHIVED
# 149     30.295057 -97.719288      3800 N IH 35 UPPER DECK NB  ARCHIVED
# 213     30.423909 -97.671690                13600 N IH 35 SB  ARCHIVED
# 215     30.213333 -97.753967  S IH 35 SVRD SB / E ST ELMO RD  ARCHIVED
# 289     30.256942 -97.737007                31-61 N IH 35 NB  ARCHIVED
# ...           ...        ...                             ...       ...
# 470908  30.386505 -97.672546     12000-12105 N IH 35 SVRD NB  ARCHIVED
# 470966  30.274747 -97.731784     N IH 35 SVRD SB / E 15TH ST  ARCHIVED
# 471372  30.189791 -97.770856                 6600 S IH 35 NB  ARCHIVED
# 471399   30.35796 -97.688077                 9300 N IH 35 NB  ARCHIVED
# 472038  30.367782 -97.682394           10308 N IH 35 SVRD SB  ARCHIVED
#
#                     Status Date                Agency
# 17      2024 Mar 06 05:10:12 AM  AUSTIN PD
# 149     2024 Apr 04 11:25:48 PM  AUSTIN PD
# 213     2024 Mar 06 06:45:25 PM  AUSTIN PD
# 215     2024 Mar 20 05:10:26 PM  AUSTIN PD
# 289     2019 Jun 20 01:00:05 AM                   NaN
# ...                         ...                   ...
# 470908  2026 Mar 14 05:10:25 PM  AUSTIN PD
# 470966  2026 Mar 15 01:20:15 AM  AUSTIN PD
# 471372  2026 Mar 18 09:45:13 AM  AUSTIN PD
# 471399  2026 Mar 19 10:35:19 PM  AUSTIN PD
# 472038  2026 Mar 23 12:30:24 PM  AUSTIN PD
#
# [2792 rows x 10 columns]

# %%
df = pd.to_datetime(df["Published Date"])
df[(df["Incident Reported"] == "Traffic Hazard") & (df["Published Date"].dt.year >= 2023)]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[56], line 2
#       1 df = pd.to_datetime(df["Published Date"])
# ----> 2 df[(df["Incident Reported"] == "Traffic Hazard") & (df["Published Date"].dt.year >= 2023)]
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/series.py:959, in Series.__getitem__(self, key)
#     954     key = unpack_1tuple(key)
#     956 elif key_is_scalar:
#     957     # Note: GH#50617 in 3.0 we changed int key to always be treated as
#     958     #  a label, matching DataFrame behavior.
# --> 959     return self._get_value(key)
#     961 # Convert generator to list before going through hashable part
#     962 # (We will iterate through the generator there to check for slices)
#     963 if is_iterator(key):
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/series.py:1046, in Series._get_value(self, label, takeable)
#    1043     return self._values[label]
#    1045 # Similar to Index.get_value, but we do not fall back to positional
# -> 1046 loc = self.index.get_loc(label)
#    1048 if is_integer(loc):
#    1049     return self._values[loc]
#
# File /opt/conda/lib/python3.12/site-packages/pandas/core/indexes/range.py:525, in RangeIndex.get_loc(self, key)
#     523         raise KeyError(key) from err
#     524 if isinstance(key, Hashable):
# --> 525     raise KeyError(key)
#     526 self._check_indexing_error(key)
#     527 raise KeyError(key)
#
# KeyError: 'Incident Reported'
